# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        

# Any results you write to the current directory are saved as output.

# %%
df1 = pd.read_csv('/kaggle/input/college-salaries/salaries-by-college-type.csv')
df3 = pd.read_csv('/kaggle/input/college-salaries/degrees-that-pay-back.csv') 
df2 = pd.read_csv('/kaggle/input/college-salaries/salaries-by-region.csv')

# %%
df3.columns

# %%
df3dict={"Undergraduate Major":"major","Starting Median Salary":"starting","Mid-Career Median Salary":"mid_career","Percent change from Starting to Mid-Career Salary":"percent_change","Mid-Career 10th Percentile Salary":"10th_percentile",
         "Mid-Career 25th Percentile Salary":"25th_percentile","Mid-Career 75th Percentile Salary":"75th_percentile",
         "Mid-Career 90th Percentile Salary":"90th_percentile"}

# %%
df1dict={"School Name":"school Name","School Type":"school_type","Starting Median Salary":"starting",
         "Mid-Career Median Salary":"mid_career","Mid-Career 10th Percentile Salary":"10th_percentile",
         "Mid-Career 25th Percentile Salary":"25th_percentile","Mid-Career 75th Percentile Salary":"75th_percentile",
         "Mid-Career 90th Percentile Salary":"90th_percentile"}

# %%
df2dict={"School Name":"school Name","Region":"region","Starting Median Salary":"starting",
         "Mid-Career Median Salary":"mid_career","Mid-Career 10th Percentile Salary":"10th_percentile",
         "Mid-Career 25th Percentile Salary":"25th_percentile","Mid-Career 75th Percentile Salary":"75th_percentile",
         "Mid-Career 90th Percentile Salary":"90th_percentile"}

# %%
df1_2=df1.rename(columns=df1dict)
df1_2

# %%
df2_2=df2.rename(columns=df2dict)
df2_2

# %%
df3_2=df3.rename(columns=df3dict)
df3_2

# %%
df1_2.insert(0, 'ID', range(0,len(df1_2)))
df2_2.insert(0, 'ID', range(0,len(df2_2)))
df3_2.insert(0, 'ID', range(0,len(df3_2)))

# %%
df3_2.head()

# %%
df1_2_c = ["starting","mid_career","10th_percentile","25th_percentile","75th_percentile","90th_percentile"]
df2_2_c = ["starting","mid_career","10th_percentile","25th_percentile","75th_percentile","90th_percentile"]
df3_2_c = ["starting","mid_career","10th_percentile","25th_percentile","75th_percentile","90th_percentile"]

# %%
for x in df1_2_c:
    df1_2[x] = df1_2[x].str.replace("$","")
    df1_2[x] = df1_2[x].str.replace(",","")
    df1_2[x] = pd.to_numeric(df1_2[x])
df1_2.head()

# %%
for x in df2_2_c:
    df2_2[x] = df2_2[x].str.replace("$","")
    df2_2[x] = df2_2[x].str.replace(",","")
    df2_2[x] = pd.to_numeric(df2_2[x])
df2_2.head()

# %%
for x in df3_2_c:
    df3_2[x] = df3_2[x].str.replace("$","")
    df3_2[x] = df3_2[x].str.replace(",","")
    df3_2[x] = pd.to_numeric(df3_2[x])
df3_2.head()

# %%
rds_connection_string= "postgres:cararose1@localhost:5432/ETLproject"
engine=create_engine(f'postgresql://{rds_connection_string}')

# %%
df1_2.to_sql(name="salaries-by-college-type",con=engine,if_exists='append',index="False")
df2_2.to_sql(name="salaries-by-region",con=engine,if_exists='append',index="False")
df3_2.to_sql(name="degrees-that-pay-back",con=engine,if_exists='append',index="False")
